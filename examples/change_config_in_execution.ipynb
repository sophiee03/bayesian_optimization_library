# %% [markdown]
# # GENERATION OF CANDIDATES WITH DIFFERENT CONFIGURATIONS

# %%
from bayesopt import *
import sys, os
sys.path.insert(0, os.path.abspath(os.path.join(os.path.join(os.getcwd()), '..')))
from etl.extractors.provenance_extractor import ProvenanceExtractor

# %%
data_needed = {
    'input': ['DROPOUT', 'BATCH_SIZE', 'EPOCHS', 'LR'],
    'output': ['accuracy', 'emissions']
}

extractor = ProvenanceExtractor('../test/prov', data_needed)
inp, out = extractor.extract_all()      # cols are parameters/metrics, rows are runs

bayesopt = BayesianOptimizer(OptimizationConfig(
    data_needed['output'],
    data_needed['input'],
    ['MAX', 'MIN'],
    ground_truth_dim=len(inp),
    n_candidates=1,
    n_restarts=2,
    raw_samples=10,
    optimizers='optimize_acqf',
    acqf='ucb',
    beta=1.5,
    verbose=True
))

data = {
    'parameters': inp,
    'metrics': out
}

for it in range(1,4):
    print(f"ITERATION {it}{'='*10}")
    bayesopt.config.details()
    res = bayesopt.run(data)

    bayesopt.change_config(
        n_cand=it+1,
        n_restarts=5*(it+1),
        raw_samples=50*(it+1),
        optimizers='optimize_acqf',
        acqf='ucb',
        beta=2,
        verbose=True
    )
# Out:
# ITERATION 1==========
# ------------------------------------------------------------
# CONFIGURATION DETAILS:
#     executing a MULTI objective model with:
#     - Parameters to optimize: ['DROPOUT', 'BATCH_SIZE', 'EPOCHS', 'LR']
#     - Metrics to maximize/minimize: ['accuracy', 'emissions']
#     The directions of the metrics are: ['MAX', 'MIN']
#     1 candidates are required to be generated, with a ground truth of 416 runs
#     It will be used a ucb acquisition function
# with optimize_acqf as optimizer setup with the following settings:
#     -> n_restarts: 2    raw_samples: 10
# ------------------------------------------------------------
#    -> Starting Bayesian Optimization
#    -> Data transformed
#    -> Bounds generated
#    -> Data normalized
#    -> Model trained
#    -> Candidates obtained
#    -> Candidates denormalized
#    -> Bayesian Optimization finished, took 2.405s
# ┌───────────┬──────────────┬───────────┬──────────┐
# │   DROPOUT │   BATCH_SIZE │    EPOCHS │       LR │
# ├───────────┼──────────────┼───────────┼──────────┤
# │  0.378944 │    15.040000 │ 13.284873 │ 0.000172 │
# └───────────┴──────────────┴───────────┴──────────┘
#    -> Estimating candidates
# ============================================================
# CANDIDATE 1
# ============================================================
# ┌───────────┬──────────┬──────────┐
# │ METRIC    │     MEAN │      STD │
# ├───────────┼──────────┼──────────┤
# │ accuracy  │ 0.704515 │ 0.057155 │
# ├───────────┼──────────┼──────────┤
# │ emissions │ 0.009637 │ 0.000372 │
# └───────────┴──────────┴──────────┘
#
# ITERATION 2==========
# ------------------------------------------------------------
# CONFIGURATION DETAILS:
#     executing a MULTI objective model with:
#     - Parameters to optimize: ['DROPOUT', 'BATCH_SIZE', 'EPOCHS', 'LR']
#     - Metrics to maximize/minimize: ['accuracy', 'emissions']
#     The directions of the metrics are: ['MAX', 'MIN']
#     2 candidates are required to be generated, with a ground truth of 416 runs
#     It will be used a ucb acquisition function
# with optimize_acqf as optimizer setup with the following settings:
#     -> n_restarts: 10    raw_samples: 100
# ------------------------------------------------------------
#    -> Starting Bayesian Optimization
#    -> Data transformed
#    -> Bounds generated
#    -> Data normalized
#    -> Model trained
#    -> Candidates obtained
#    -> Candidates denormalized
#    -> Bayesian Optimization finished, took 2.266s
# ┌───────────┬──────────────┬───────────┬──────────┐
# │   DROPOUT │   BATCH_SIZE │    EPOCHS │       LR │
# ├───────────┼──────────────┼───────────┼──────────┤
# │  0.462145 │    64.960000 │ 15.200000 │ 0.000898 │
# ├───────────┼──────────────┼───────────┼──────────┤
# │  0.452820 │    15.040000 │ 14.633640 │ 0.000184 │
# └───────────┴──────────────┴───────────┴──────────┘
#    -> Estimating candidates
# ============================================================
# CANDIDATE 1
# ============================================================
# ┌───────────┬───────────┬──────────┐
# │ METRIC    │      MEAN │      STD │
# ├───────────┼───────────┼──────────┤
# │ accuracy  │  0.647288 │ 0.076490 │
# ├───────────┼───────────┼──────────┤
# │ emissions │ -0.005485 │ 0.000931 │
# └───────────┴───────────┴──────────┘
#
# ============================================================
# CANDIDATE 2
# ============================================================
# ┌───────────┬───────────┬──────────┐
# │ METRIC    │      MEAN │      STD │
# ├───────────┼───────────┼──────────┤
# │ accuracy  │  0.693288 │ 0.064944 │
# ├───────────┼───────────┼──────────┤
# │ emissions │ -0.010291 │ 0.000413 │
# └───────────┴───────────┴──────────┘
#
# ITERATION 3==========
# ------------------------------------------------------------
# CONFIGURATION DETAILS:
#     executing a MULTI objective model with:
#     - Parameters to optimize: ['DROPOUT', 'BATCH_SIZE', 'EPOCHS', 'LR']
#     - Metrics to maximize/minimize: ['accuracy', 'emissions']
#     The directions of the metrics are: ['MAX', 'MIN']
#     3 candidates are required to be generated, with a ground truth of 416 runs
#     It will be used a ucb acquisition function
# with optimize_acqf as optimizer setup with the following settings:
#     -> n_restarts: 15    raw_samples: 150
# ------------------------------------------------------------
#    -> Starting Bayesian Optimization
#    -> Data transformed
#    -> Bounds generated
#    -> Data normalized
#    -> Model trained
#    -> Candidates obtained
#    -> Candidates denormalized
#    -> Bayesian Optimization finished, took 3.052s
# ┌───────────┬──────────────┬───────────┬──────────┐
# │   DROPOUT │   BATCH_SIZE │    EPOCHS │       LR │
# ├───────────┼──────────────┼───────────┼──────────┤
# │  0.097224 │    37.610118 │  4.800000 │ 0.000362 │
# ├───────────┼──────────────┼───────────┼──────────┤
# │  0.407592 │    26.964983 │ 13.311634 │ 0.000191 │
# ├───────────┼──────────────┼───────────┼──────────┤
# │  0.463233 │    64.960000 │ 15.200000 │ 0.000897 │
# └───────────┴──────────────┴───────────┴──────────┘
#    -> Estimating candidates
# ============================================================
# CANDIDATE 1
# ============================================================
# ┌───────────┬──────────┬──────────┐
# │ METRIC    │     MEAN │      STD │
# ├───────────┼──────────┼──────────┤
# │ accuracy  │ 0.591311 │ 0.087615 │
# ├───────────┼──────────┼──────────┤
# │ emissions │ 0.002589 │ 0.001564 │
# └───────────┴──────────┴──────────┘
#
# ============================================================
# CANDIDATE 2
# ============================================================
# ┌───────────┬──────────┬──────────┐
# │ METRIC    │     MEAN │      STD │
# ├───────────┼──────────┼──────────┤
# │ accuracy  │ 0.685967 │ 0.068127 │
# ├───────────┼──────────┼──────────┤
# │ emissions │ 0.008170 │ 0.000461 │
# └───────────┴──────────┴──────────┘
#
# ============================================================
# CANDIDATE 3
# ============================================================
# ┌───────────┬──────────┬──────────┐
# │ METRIC    │     MEAN │      STD │
# ├───────────┼──────────┼──────────┤
# │ accuracy  │ 0.646924 │ 0.076641 │
# ├───────────┼──────────┼──────────┤
# │ emissions │ 0.005485 │ 0.000935 │
# └───────────┴──────────┴──────────┘
