# %% [markdown]
# # GENERATION OF CANDIDATES WITH DIFFERENT CONFIGURATIONS

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from bayesopt_core import *
import sys, os
sys.path.insert(0, os.path.abspath(os.path.join(os.path.join(os.getcwd()), '..')))
from etl.extractors.provenance_extractor import ProvenanceExtractor

# %%
data_needed = {
    'input': ['DROPOUT', 'BATCH_SIZE', 'EPOCHS', 'LR'],
    'output': ['accuracy', 'emissions']
}
extractor = ProvenanceExtractor('../test/prov', data_needed)
inp, out = extractor.extract_all()      # cols are parameters/metrics, rows are runs

bayesopt = BayesianOptimizer(OptimizationConfig(
    data_needed['output'],
    data_needed['input'],
    ['MAX', 'MIN'],
    n_candidates=3,
    n_restarts=10,
    raw_samples=200,
    optimizers='optimize_acqf',
    acqf='ucb',
    beta=1.5,
    verbose=True
))

data = {
    'parameters': inp,
    'metrics': out
}

for it in range(3):
    res = bayesopt.run(data)

    bayesopt.change_config(OptimizationConfig(
        data_needed['output'],
        data_needed['input'],
        ['MAX', 'MIN'],
        n_candidates=it+1,
        n_restarts=5*(it+1),
        raw_samples=50*(it+1),
        optimizers='optimize_acqf',
        acqf='ucb',
        beta=2,
        verbose=True
    ))
# Out:
#    -> Starting Bayesian Optimization
#    -> Data transformed
#    -> Bounds generated
#    -> Data normalized
#    -> Model trained
#    -> Candidates obtained
#    -> Candidates denormalized
#    -> Bayesian Optimization finished, took 5.008s
# ┌───────────┬──────────────┬───────────┬──────────┐
# │   DROPOUT │   BATCH_SIZE │    EPOCHS │       LR │
# ├───────────┼──────────────┼───────────┼──────────┤
# │  0.092000 │    16.680041 │  4.800000 │ 0.000229 │
# ├───────────┼──────────────┼───────────┼──────────┤
# │  0.463175 │    64.960000 │ 15.200000 │ 0.000902 │
# ├───────────┼──────────────┼───────────┼──────────┤
# │  0.508000 │    15.040000 │ 15.200000 │ 0.000176 │
# └───────────┴──────────────┴───────────┴──────────┘
#    -> Estimating candidates
# ============================================================
# CANDIDATE 1
# ============================================================
# ┌───────────┬──────────┬──────────┐
# │ METRIC    │     MEAN │      STD │
# ├───────────┼──────────┼──────────┤
# │ accuracy  │ 0.637040 │ 0.081573 │
# ├───────────┼──────────┼──────────┤
# │ emissions │ 0.002520 │ 0.000687 │
# └───────────┴──────────┴──────────┘
#
# ============================================================
# CANDIDATE 2
# ============================================================
# ┌───────────┬──────────┬──────────┐
# │ METRIC    │     MEAN │      STD │
# ├───────────┼──────────┼──────────┤
# │ accuracy  │ 0.650719 │ 0.075008 │
# ├───────────┼──────────┼──────────┤
# │ emissions │ 0.005485 │ 0.000896 │
# └───────────┴──────────┴──────────┘
#
# ============================================================
# CANDIDATE 3
# ============================================================
# ┌───────────┬──────────┬──────────┐
# │ METRIC    │     MEAN │      STD │
# ├───────────┼──────────┼──────────┤
# │ accuracy  │ 0.700676 │ 0.059947 │
# ├───────────┼──────────┼──────────┤
# │ emissions │ 0.010418 │ 0.000371 │
# └───────────┴──────────┴──────────┘
#
# Successfully changed BayesianOptimizer configuration
#    -> Starting Bayesian Optimization
#    -> Data transformed
#    -> Bounds generated
#    -> Data normalized
#    -> Model trained
#    -> Candidates obtained
#    -> Candidates denormalized
#    -> Bayesian Optimization finished, took 2.312s
# ┌───────────┬──────────────┬───────────┬──────────┐
# │   DROPOUT │   BATCH_SIZE │    EPOCHS │       LR │
# ├───────────┼──────────────┼───────────┼──────────┤
# │  0.438472 │    15.040000 │ 14.686974 │ 0.000176 │
# └───────────┴──────────────┴───────────┴──────────┘
#    -> Estimating candidates
# ============================================================
# CANDIDATE 1
# ============================================================
# ┌───────────┬───────────┬──────────┐
# │ METRIC    │      MEAN │      STD │
# ├───────────┼───────────┼──────────┤
# │ accuracy  │  0.700546 │ 0.060311 │
# ├───────────┼───────────┼──────────┤
# │ emissions │ -0.010283 │ 0.000369 │
# └───────────┴───────────┴──────────┘
#
# Successfully changed BayesianOptimizer configuration
#    -> Starting Bayesian Optimization
#    -> Data transformed
#    -> Bounds generated
#    -> Data normalized
#    -> Model trained
#    -> Candidates obtained
#    -> Candidates denormalized
#    -> Bayesian Optimization finished, took 3.111s
# ┌───────────┬──────────────┬───────────┬──────────┐
# │   DROPOUT │   BATCH_SIZE │    EPOCHS │       LR │
# ├───────────┼──────────────┼───────────┼──────────┤
# │  0.463101 │    64.960000 │ 15.200000 │ 0.000900 │
# ├───────────┼──────────────┼───────────┼──────────┤
# │  0.395976 │    24.120478 │ 13.159831 │ 0.000187 │
# └───────────┴──────────────┴───────────┴──────────┘
#    -> Estimating candidates
# ============================================================
# CANDIDATE 1
# ============================================================
# ┌───────────┬──────────┬──────────┐
# │ METRIC    │     MEAN │      STD │
# ├───────────┼──────────┼──────────┤
# │ accuracy  │ 0.649314 │ 0.075629 │
# ├───────────┼──────────┼──────────┤
# │ emissions │ 0.005485 │ 0.000911 │
# └───────────┴──────────┴──────────┘
#
# ============================================================
# CANDIDATE 2
# ============================================================
# ┌───────────┬──────────┬──────────┐
# │ METRIC    │     MEAN │      STD │
# ├───────────┼──────────┼──────────┤
# │ accuracy  │ 0.689761 │ 0.066236 │
# ├───────────┼──────────┼──────────┤
# │ emissions │ 0.008452 │ 0.000442 │
# └───────────┴──────────┴──────────┘
#
# Successfully changed BayesianOptimizer configuration
